# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir('gdrive/My Drive/NLA PROJECT')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_4884 = [2176, 1248, 576, 160]
y_4884 = [0.9806, 0.9783, 0.9779, 0.971]

x_44444 = [896, 528, 256, 80]
y_44444 = [0.9777, 0.9759, 0.9732, 0.9691]

x_3232 = [8192, 6144, 4096, 2048]
y_3232 = [0.9792, 0.9804, 0.9818, 0.9753]

x_228822 = [2208, 1248, 560, 144]
y_228822 = [0.9791, 0.9762, 0.9727, 0.9655]

x_244442 = [1056, 600, 272, 72]
y_244442 = [0.9777, 0.9759, 0.9695, 0.9673]

x_210 = [544, 144, 40]
y_210 = [0.9714, 0.9694, 0.9583]

x = [1048576]
y = [0.9675]

# %%
plt.figure(figsize=(10, 6))
plt.plot([x], [y], "o", markersize=10, label = u'uncompressed')
plt.plot(x_3232, y_3232, "o", linestyle = "-", color='b', label = u'32x32')
plt.plot(x_4884, y_4884, "o", linestyle = "-", color='c', label = u'4x8x8x4')
plt.plot(x_44444, y_44444, "o", linestyle = "-", color='r', label = u'4x4x4x4x4')
plt.plot(x_228822, y_228822, "o", linestyle = "-", color='purple',label = u'2x2x8x8x2x2')
plt.plot(x_244442, y_244442, "o", linestyle = "-", color='orange',label = u'2x4x4x4x4x2')
plt.plot(x_210, y_210, "o", color='green', linestyle = "-", label = u'2^10')
plt.xlabel('Number of parameters in the weight matrix of the first layer', fontsize=15)
plt.ylabel('Accuracy score', fontsize=15)
plt.title('MNIST', fontsize=15)
plt.xscale('log')
plt.legend()
plt.savefig('mnist.eps', format='eps', dpi=1000)
plt.show()

# %%
x_8886 = [228, 712, 1452, 2448]
y_8886 = [0.3936, 0.4217, 0.4101, 0.4326]

x_8886_10 = [300, 920, 1860, 3120]
y_8886_10 = [0.4827, 0.4897, 0.4937, 0.488]

x_88832 = [205, 684, 1437, 2464]
y_88832 = [0.3911, 0.4025, 0.4117, 0.4188]

x_88832_10 = [290, 960, 2010, 3440]
y_88832_10 = [0.5379, 0.5467, 0.5444, 0.5567]

x_44486 = [148, 488, 1020, 1744]
y_44486 = [0.39, 0.40, 0.41, 0.44]

x_44486_10 = [260, 840, 1740, 2960]
y_44486_10 = [0.55, 0.56, 0.5595, 0.5645]

x_24886 = [184, 656, 1416, 2464]
y_24886 = [0.3894, 0.3997, 0.4024, 0.415]

x_24886_10 = [280, 960, 2040, 3520]
y_24886_10 = [0.5424, 0.5596, 0.5601, 0.5503]

x_6486 = [4196, 8520, 12972, 17552]
y_6486 = [ 0.4185, 0.44, 0.43, 0.45]

x_32166 = [1316, 3144, 5484, 8336]
y_32166 = [0.45, 0.45, 0.4474, 0.45]

x_32166_10 = [3420, 7160, 11220, 15600]
y_32166_10 = [0.502, 0.5289, 0.5346, 0.5306]

x = []
y = []

# %%
plt.figure(figsize=(12, 8))
plt.plot(x_88832_10, y_88832_10, "o", linestyle = "--", label = u'in 8x8x8x3x2, out 10^5', color='c')
plt.plot(x_24886_10, y_24886_10, "o", linestyle = "--", label = u'in 2x4x8x8x6, out 10^5', color='red')
plt.plot(x_44486_10, y_44486_10, "o", linestyle = "--", label = u'in 4x4x4x8x6, out 10^5', color='blueviolet')
plt.plot(x_8886_10, y_8886_10, "o", linestyle = "--", label = u'in 8x8x8x6 out, 10^4', color='blue')
plt.plot(x_32166_10, y_32166_10, "o", linestyle = "--", label = u'in 32x16x6, out 10^4', color='lime')
plt.xlabel('Number of parameters in the weight matrix of the first layer,\n different sizes of input and hidden layer', fontsize=20)
plt.ylabel('Accuracy score', fontsize=20)
plt.title('CIFAR10', fontsize=20)
plt.xscale('log')
plt.legend(prop={'size': 14})
plt.savefig('cifar1.eps', format='eps', dpi=1000)
plt.show()

# %%
plt.figure(figsize=(12, 8))
#plt.plot(x, y, "o", label = u'uncompressed')
# plt.plot(x_8886_10, y_8886_10, "o", linestyle = "--", label = u'in_8x8x8x6 out_10^4', color='blue')
plt.plot(x_8886, y_8886, "o", linestyle = "-", label = u'8x8x8x6', color='blue')

# plt.plot(x_88832_10, y_88832_10, "o", linestyle = "--", label = u'in_8x8x8x3x2 out_10^5', color='c')
plt.plot(x_88832, y_88832, "o", linestyle = "-", label = u'8x8x8x3x2', color='c')

# plt.plot(x_24886_10, y_24886_10, "o", linestyle = "--", label = u'in_2x4x8x8x6 out_10^5', color='red')
plt.plot(x_24886, y_24886, "o", linestyle = "-", label = u'2x4x8x8x6', color='red')

# plt.plot(x_44486_10, y_44486_10, "o", linestyle = "--", label = u'in_4x4x4x8x6 out_10^5', color='blueviolet')
plt.plot(x_44486, y_44486, "o", linestyle = "-", label = u'4x4x4x8x6', color='blueviolet')

plt.plot(x_6486, y_6486, "o", linestyle = "-", label = u'64x8x6', color='deeppink')
plt.xlabel('Number of parameters in the weight matrix of the first layer, \n the same size of input and hidden layer', fontsize=20)
plt.ylabel('Accuracy score', fontsize=20)
plt.title('CIFAR10', fontsize=20)
plt.xscale('log')
plt.legend(prop={'size': 18})
plt.savefig('cifar2.eps', format='eps', dpi=1000)
plt.show()

# %%
x_32166_10 = [3420, 7160, 11220, 15600]
y_32166_10 = [0.502, 0.5289, 0.5346, 0.5306]

x_32166 = [1316, 3144, 5484, 8336]
y_32166 = [0.45, 0.45, 0.4474, 0.45]

x_out10_5 = [4860, 12920, 24180, 38640]
y_out10_5 = [0.5698, 0.5864, 0.5851, 0.5755]

# %%
plt.figure(figsize=(12, 8))
plt.plot(x_32166, y_32166, "o", linestyle = "--", label = u'out 32x16x6', color='c')
plt.plot(x_32166_10, y_32166_10, "o", linestyle = "--", label = u'out 10^4', color='blue')
plt.plot(x_out10_5, y_out10_5, "o", linestyle = "--", label = u'out 10^5', color='blueviolet')

plt.xlabel('Number of parameters in the weight matrix of the first layer,\n different sizes of input and hidden layer', fontsize=20)
plt.ylabel('Accuracy score', fontsize=20)
plt.title('CIFAR10. Input 32x16x6', fontsize=20)
plt.xscale('log')
plt.legend(prop={'size': 14})
plt.show()
plt.savefig("Last_plot.png")
