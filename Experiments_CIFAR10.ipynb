# %% [markdown]
# ## Experiments with rank of core tensors and shape of input tensor on the CIFAR10 dataset

# %%
import numpy as np

import keras.activations
from keras import backend as K
from keras.engine.topology import Layer

from keras import activations
from keras import initializers
from keras import regularizers
from keras import constraints

from keras.datasets import cifar10, cifar100
from keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# (x_train, y_train), (x_test, y_test) = cifar100.load_data()

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.
# ...
# 170500096/170498071 [==============================] - 26s 0us/step

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# path_to_nla_folder = 'gdrive/My Drive/NLA PROJECT'

# %%
import os
os.chdir('gdrive/My Drive/NLA PROJECT')

# %%
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras.optimizers import *

from TTLayer import *

tt_input_shape=[ 32, 16, 6]
tt_output_shape=[100, 100, 10]
tt_ranks=[1, 4, 4, 1]

input = Input((32, 32, 3))
ttl = TT_Layer(tt_input_shape=tt_input_shape, tt_output_shape=tt_output_shape,
               tt_ranks=tt_ranks,
               activation='relu', use_bias=True,
               kernel_regularizer=regularizers.l2(.001), )
z1 = ttl(input)
z1 = Dropout(.5)(z1)
output = Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(.01),)(z1)
# Out:
# Compression factor = 38640 / 307200000 = 0.00012578125

# %%
model = Model(input, output)

model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=[x_test, y_test], verbose=2)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
#  - 20s - loss: 13.6783 - acc: 0.1604 - val_loss: 13.6510 - val_acc: 0.1677
# Epoch 2/100
#  - 17s - loss: 13.6049 - acc: 0.1699 - val_loss: 13.5024 - val_acc: 0.1770
# Epoch 3/100
#  - 17s - loss: 13.5328 - acc: 0.1741 - val_loss: 13.4372 - val_acc: 0.1795
# Epoch 4/100
#  - 17s - loss: 12.8768 - acc: 0.2022 - val_loss: 12.2439 - val_acc: 0.2281
# Epoch 5/100
#  - 17s - loss: 10.2568 - acc: 0.2596 - val_loss: 3.8986 - val_acc: 0.3664
# Epoch 6/100
#  - 17s - loss: 3.4196 - acc: 0.4391 - val_loss: 3.2093 - val_acc: 0.4698
# Epoch 7/100
#  - 18s - loss: 2.2891 - acc: 0.5335 - val_loss: 1.6943 - val_acc: 0.5381
# Epoch 8/100
#  - 18s - loss: 1.5110 - acc: 0.6087 - val_loss: 1.6705 - val_acc: 0.5550
# Epoch 9/100
#  - 18s - loss: 1.4124 - acc: 0.6416 - val_loss: 1.6179 - val_acc: 0.5680
# Epoch 10/100
#  - 18s - loss: 1.3424 - acc: 0.6670 - val_loss: 1.5957 - val_acc: 0.5855
# Epoch 11/100
# ...

# %%
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score

# %%
# Predicted values:
Y_pred = model.predict(x=x_test)
#print (roc_auc_score(y_test, Y_pred))
print (average_precision_score(y_test, Y_pred))
print (accuracy_score(y_test, np.round(Y_pred)))
# Out:
# 0.6582833916671419
# 0.5776

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# (x_train, y_train), (x_test, y_test) = cifar100.load_data()

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

tt_input_shape=[ 8, 8, 8, 3, 2]
tt_output_shape=[10, 10, 10, 10, 10]
tt_ranks=[1, 3, 3, 3, 3, 1]

input = Input((32, 32, 3))
ttl = TT_Layer(tt_input_shape=tt_input_shape, tt_output_shape=tt_output_shape,
               tt_ranks=tt_ranks,
               activation='relu', use_bias=True,
               kernel_regularizer=regularizers.l2(.001), )
z1 = ttl(input)
z1 = Dropout(.5)(z1)
output = Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(.01),)(z1)
# Out:
# Compression factor = 2010 / 307200000 = 6.54296875e-06

# %%
model = Model(input, output)

model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=[x_test, y_test], verbose=2)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
#  - 42s - loss: 4.5578 - acc: 0.3133 - val_loss: 3.1436 - val_acc: 0.4475
# Epoch 2/100
#  - 42s - loss: 3.1357 - acc: 0.4248 - val_loss: 1.6317 - val_acc: 0.5127
# Epoch 3/100
#  - 42s - loss: 1.6538 - acc: 0.5117 - val_loss: 1.5794 - val_acc: 0.5320
# Epoch 4/100
#  - 42s - loss: 1.5231 - acc: 0.5538 - val_loss: 1.5427 - val_acc: 0.5404
# Epoch 5/100
#  - 42s - loss: 1.4417 - acc: 0.5848 - val_loss: 1.5169 - val_acc: 0.5493
# Epoch 6/100
#  - 42s - loss: 1.3901 - acc: 0.6046 - val_loss: 1.5138 - val_acc: 0.5571
# Epoch 7/100
#  - 42s - loss: 1.3474 - acc: 0.6201 - val_loss: 1.5118 - val_acc: 0.5541
# Epoch 8/100
#  - 42s - loss: 1.3132 - acc: 0.6319 - val_loss: 1.4946 - val_acc: 0.5694
# Epoch 9/100
#  - 42s - loss: 1.2871 - acc: 0.6424 - val_loss: 1.5131 - val_acc: 0.5591
# Epoch 10/100
#  - 42s - loss: 1.2618 - acc: 0.6534 - val_loss: 1.4983 - val_acc: 0.5687
# Epoch 11/100
# ...

# %%
# Predicted values:
Y_pred = model.predict(x=x_test)
#print (roc_auc_score(y_test, Y_pred))
print (average_precision_score(y_test, Y_pred))
print (accuracy_score(y_test, np.round(Y_pred)))
# Out:
# 0.6428084584531184
# 0.5567
